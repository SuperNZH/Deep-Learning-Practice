# %% [markdown]
# <a href="https://colab.research.google.com/github/SuperNZH/Deep-Learning-Practice/blob/main/Dive%20in%20DL/6.0_House_Prediction_Competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Needed Library and Read Dataset

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import torch
import torch.nn as nn
torch.set_default_tensor_type(torch.FloatTensor)
import sys

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read data
train_data = pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/dataset/house_price_data/train.csv")
test_data = pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/dataset/house_price_data/test.csv")

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %% [markdown]
# # Preprocess the dataset

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
# process the dataset of Train&Test together, that's wahy concat them.

all_features = pd.concat((train_data.iloc[:, 1:-1], test_data.iloc[:, 1:]))

# %%
all_features
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0             60       RL         65.0  ...    2008       WD        Normal
# 1             20       RL         80.0  ...    2007       WD        Normal
# 2             60       RL         68.0  ...    2008       WD        Normal
# 3             70       RL         60.0  ...    2006       WD       Abnorml
# 4             60       RL         84.0  ...    2008       WD        Normal
# ...          ...      ...          ...  ...     ...      ...           ...
# 1454         160       RM         21.0  ...    2006       WD        Normal
# 1455         160       RM         21.0  ...    2006       WD       Abnorml
# 1456          20       RL        160.0  ...    2006       WD       Abnorml
# 1457          85       RL         62.0  ...    2006       WD        Normal
# 1458          60       RL         74.0  ...    2006       WD        Normal
#
# [2919 rows x 79 columns]

# %%
# Standardization
# https://www.jianshu.com/p/fa73a07cd750 Article about standardization
# Use Z-score

numerical_features = all_features.dtypes[all_features.dtypes != "object"].index
all_features[numerical_features] = all_features[numerical_features].apply(lambda x: (x-x.mean())/(x.std()))
all_features = all_features.fillna(0)

# %%
all_features
# Out:
#       MSSubClass MSZoning  LotFrontage  ...    YrSold SaleType SaleCondition
# 0       0.067320       RL    -0.184443  ...  0.157619       WD        Normal
# 1      -0.873466       RL     0.458096  ... -0.602858       WD        Normal
# 2       0.067320       RL    -0.055935  ...  0.157619       WD        Normal
# 3       0.302516       RL    -0.398622  ... -1.363335       WD       Abnorml
# 4       0.067320       RL     0.629439  ...  0.157619       WD        Normal
# ...          ...      ...          ...  ...       ...      ...           ...
# 1454    2.419286       RM    -2.069222  ... -1.363335       WD        Normal
# 1455    2.419286       RM    -2.069222  ... -1.363335       WD       Abnorml
# 1456   -0.873466       RL     3.884968  ... -1.363335       WD       Abnorml
# 1457    0.655311       RL    -0.312950  ... -1.363335       WD        Normal
# 1458    0.067320       RL     0.201080  ... -1.363335       WD        Normal
#
# [2919 rows x 79 columns]

# %%
# transform discretive features into Indicator Features

all_features = pd.get_dummies(all_features, dummy_na=True)

# %%
all_features
# Out:
#       MSSubClass  LotFrontage  ...  SaleCondition_Partial  SaleCondition_nan
# 0       0.067320    -0.184443  ...                      0                  0
# 1      -0.873466     0.458096  ...                      0                  0
# 2       0.067320    -0.055935  ...                      0                  0
# 3       0.302516    -0.398622  ...                      0                  0
# 4       0.067320     0.629439  ...                      0                  0
# ...          ...          ...  ...                    ...                ...
# 1454    2.419286    -2.069222  ...                      0                  0
# 1455    2.419286    -2.069222  ...                      0                  0
# 1456   -0.873466     3.884968  ...                      0                  0
# 1457    0.655311    -0.312950  ...                      0                  0
# 1458    0.067320     0.201080  ...                      0                  0
#
# [2919 rows x 354 columns]

# %%
# Prepare the train/test dataset

n_train = train_data.shape[0]
# the reason why using ".values" is becuase tensor do not cover columns when doing model training in Deep learning.
train_features = torch.tensor(all_features[:n_train].values, dtype=torch.float)
test_features = torch.tensor(all_features[n_train:].values, dtype=torch.float)
# X and y should have the same data dimension(2D), that's why use view to make 1D train_labels be 2D dimension.
train_labels = torch.tensor(train_data.SalePrice.values, dtype=torch.float).view(-1,1)

# %% [markdown]
# # Model Training

# %%
# Use a simple linear regression model and MSE to train the model.

loss = torch.nn.MSELoss()

def get_net(feature_num):
